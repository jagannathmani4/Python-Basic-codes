# %%
a = 4
b = 7
c = 2
print(60&512)
# Out:
# 0

# %% [markdown]
# ## check numeric

# %%
num = input("Enter a value:")
if num.isnumeric():
    print("This is a number")
else:
    print("This is a alphabet")
# Out:
# Enter a value: 5464
# This is a number

# %%
def myfunc(lists):
    if not lists:
        return
    print(lists[0]) #2
    myfunc(lists[-4:-1]) #0 2 3 4
myfunc([1,2,3,4,5])
# Out:
# 1
# 2
# 2
# 2

# %%
list1 = [2,3,4]
print(list1[-4:-1])
# Out:
# [2, 3]

# %%
list1 = [1,2,3,4,5]
