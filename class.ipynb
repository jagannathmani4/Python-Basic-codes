# %%
class Employee:
    def __init__(self, fname, lname, salary):
        self.idnum = None   # or generate an ID
        self.fname = fname
        self.lname = lname
        self.salary = salary
        self.benefits = 1000

    def getsalary(self):
        return self.salary


# Create an object
emp = Employee("John", "Doe", 50000)
emp2 = Employee("Jagannath", "Mani", 40000)

print(emp2.getsalary())

# Print salary
print(emp.getsalary())
# Out:
# 40000
# 50000
